# %% [markdown]
# Load Breast Cancel

# %%
# Import Librabry 
import numpy as np
import csv

# %%
csvfile = open("./data.csv", "r")
reader_variable = csv.reader(csvfile, delimiter=",")
for data in reader_variable:
   print(data[:5])
# Out:
# ['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean']
# ['842302', 'M', '17.99', '10.38', '122.8']
# ['842517', 'M', '20.57', '17.77', '132.9']
# ['84300903', 'M', '19.69', '21.25', '130']
# ['84348301', 'M', '11.42', '20.38', '77.58']
# ['84358402', 'M', '20.29', '14.34', '135.1']
# ['843786', 'M', '12.45', '15.7', '82.57']
# ['844359', 'M', '18.25', '19.98', '119.6']
# ['84458202', 'M', '13.71', '20.83', '90.2']
# ['844981', 'M', '13', '21.82', '87.5']
# ['84501001', 'M', '12.46', '24.04', '83.97']
# ['845636', 'M', '16.02', '23.24', '102.7']
# ['84610002', 'M', '15.78', '17.89', '103.6']
# ['846226', 'M', '19.17', '24.8', '132.4']
# ['846381', 'M', '15.85', '23.95', '103.7']
# ['84667401', 'M', '13.73', '22.61', '93.6']
# ['84799002', 'M', '14.54', '27.54', '96.73']
# ['848406', 'M', '14.68', '20.13', '94.74']
# ['84862001', 'M', '16.13', '20.68', '108.1']
# ['849014', 'M', '19.81', '22.15', '130']
# ['8510426', 'B', '13.54', '14.36', '87.46']
# ...
