# %%
##Amit PAtil

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
 #load the data 
df = pd.read_csv("gt_2013 (1).csv")

df.head()
# Out:
#        AT      AP      AH    AFDP    GTEP     TIT     TAT     TEY     CDP  \
# 0  9.3779  1020.1  90.262  2.3927  19.166  1043.6  541.16  110.16  10.564
# 1  9.2985  1019.9  89.934  2.3732  19.119  1039.9  538.94  109.23  10.572
# 2  9.1337  1019.8  89.868  2.3854  19.178  1041.0  539.47  109.62  10.543
# 3  8.9715  1019.3  89.490  2.3825  19.180  1037.1  536.89  108.88  10.458
# 4  9.0157  1019.1  89.099  2.4044  19.206  1043.5  541.25  110.09  10.464
#
#         CO      NOX
# 0   9.3472   98.741
# 1  11.0160  104.290
# 2  10.7500  103.470
# 3  12.2870  108.810
# 4   9.8229  100.020

# %%
# get summary of the dataset 
print(df.describe())
# get more information about the variables
print(df.info())
# Out:
#                AT           AP           AH         AFDP         GTEP  \
# count  7152.00000  7152.000000  7152.000000  7152.000000  7152.000000
# mean     17.60262  1011.999607    80.461624     3.695958    25.105097
# std       6.86289     6.290065    14.125390     0.805829     4.350711
# min       0.28985   989.380000    27.504000     2.329500    18.104000
# 25%      12.04875  1008.400000    71.493500     3.100350    21.385000
# 50%      17.20450  1011.800000    84.002000     3.627850    24.852500
# 75%      23.16400  1016.000000    91.579000     4.156825    26.385750
# max      33.87300  1029.700000   100.190000     6.977900    36.950000
#
#                TIT          TAT          TEY          CDP           CO  \
# count  7152.000000  7152.000000  7152.000000  7152.000000  7152.000000
# mean   1081.569463   545.780885   132.168342    11.971586     2.723031
# std      17.385147     7.358935    16.348156     1.132159     2.363913
# min    1022.100000   518.320000   101.480000     9.875400     0.005033
# 25%    1065.975000   543.745000   118.005000    11.001250     1.257975
# 50%    1087.300000   549.900000   133.570000    11.956000     1.782700
# 75%    1094.400000   550.030000   135.520000    12.319250     3.591225
# max    1100.500000   550.530000   172.960000    14.867000    35.045000
#
#                NOX
# count  7152.000000
# mean     70.007899
# std      12.048249
# min      43.198000
# 25%      62.269000
# 50%      68.651000
# 75%      76.001500
# max     119.910000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7152 entries, 0 to 7151
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AT      7152 non-null   float64
#  1   AP      7152 non-null   float64
#  2   AH      7152 non-null   float64
#  3   AFDP    7152 non-null   float64
#  4   GTEP    7152 non-null   float64
#  5   TIT     7152 non-null   float64
#  6   TAT     7152 non-null   float64
#  7   TEY     7152 non-null   float64
#  8   CDP     7152 non-null   float64
#  9   CO      7152 non-null   float64
#  10  NOX     7152 non-null   float64
# dtypes: float64(11)
# memory usage: 614.8 KB
# None

# %%
# create histogram for each variabel to check normality.
df.hist(bins = 30, figsize= (10, 10) )
plt.show()

# %%
# Check the outliers 

df.boxplot(figsize = (10, 10), widths = 1)
# Out:
# <AxesSubplot:>

# %%
# creating head map with correlation values. 

'''
The code below is copied from:
https://stackoverflow.com/questions/39409866/correlation-heatmap
'''
# import the packages
import seaborn as sns

cmap = cmap=sns.diverging_palette(5, 250, as_cmap=True)

def magnify():
    return [dict(selector="th",
                 props=[("font-size", "7pt")]),
            dict(selector="td",
                 props=[('padding', "0em 0em")]),
            dict(selector="th:hover",
                 props=[("font-size", "12pt")]),
            dict(selector="tr:hover td:hover",
                 props=[('max-width', '200px'),
                        ('font-size', '12pt')])
]
corr = df.corr()
corr.style.background_gradient(cmap, axis=1)\
    .set_properties(**{'max-width': '80px', 'font-size': '10pt'})\
    .set_caption("Hover to magify")\
    .set_precision(2)\
    .set_table_styles(magnify())
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_212\224050076.py:24: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   corr.style.background_gradient(cmap, axis=1)\
# <style type="text/css">
# #T_b2a9e th {
#   font-size: 7pt;
# }
# #T_b2a9e td {
#   padding: 0em 0em;
# }
# #T_b2a9e th:hover {
#   font-size: 12pt;
# }
# #T_b2a9e tr:hover td:hover {
#   max-width: 200px;
#   font-size: 12pt;
# }
# #T_b2a9e_row0_col0, #T_b2a9e_row1_col1, #T_b2a9e_row2_col2, #T_b2a9e_row3_col3, #T_b2a9e_row4_col4, #T_b2a9e_row4_col8, #T_b2a9e_row5_col5, #T_b2a9e_row6_col6, #T_b2a9e_row7_col7, #T_b2a9e_row8_col4, #T_b2a9e_row8_col8, #T_b2a9e_row9_col9, #T_b2a9e_row10_col10 {
#   background-color: #4479bb;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_b2a9e_row0_col1 {
#   background-color: #e48fa0;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_b2a9e_row0_col2, #T_b2a9e_row1_col6, #T_b2a9e_row2_col0, #T_b2a9e_row3_col2, #T_b2a9e_row3_col9, #T_b2a9e_row4_col6, #T_b2a9e_row5_col9, #T_b2a9e_row6_col4, #T_b2a9e_row7_col6, #T_b2a9e_row8_col6, #T_b2a9e_row9_col5, #T_b2a9e_row10_col0 {
#   background-color: #d73c5b;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_b2a9e_row0_col3 {
#   background-color: #9eb8d8;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_b2a9e_row0_col4 {
#   background-color: #eab9c3;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_b2a9e_row0_col5, #T_b2a9e_row7_col10 {
#   background-color: #efdde0;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_b2a9e_row0_col6, #T_b2a9e_row9_col2 {
#   background-color: #d4dde9;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_b2a9e_row0_col7 {
#   background-color: #e69ead;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_b2a9e_row0_col8, #T_b2a9e_row4_col2 {
#   background-color: #e9b4be;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_b2a9e_row0_col9 {
#   background-color: #e6a0ae;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_b2a9e_row0_col10, #T_b2a9e_row1_col0 {
#   background-color: #d83e5d;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_b2a9e_row1_col2 {
#   background-color: #e17c90;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_b2a9e_row1_col3 {
#   background-color: #e28799;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_b2a9e_row1_col4, #T_b2a9e_row2_col1 {
#   background-color: #ebbfc8;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_b2a9e_row1_col5, #T_b2a9e_row7_col0, #T_b2a9e_row8_col2 {
#   background-color: #e9b1bc;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_b2a9e_row1_col7 {
#   background-color: #ecc3cb;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_b2a9e_row1_col8, #T_b2a9e_row2_col6, #T_b2a9e_row5_col10 {
#   background-color: #ecc5cc;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_b2a9e_row1_col9, #T_b2a9e_row3_col6 {
#   background-color: #dd6179;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_b2a9e_row1_col10 {
#   background-color: #e69dab;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_b2a9e_row2_col3, #T_b2a9e_row9_col7 {
#   background-color: #db5771;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_b2a9e_row2_col4, #T_b2a9e_row10_col6 {
#   background-color: #e599a8;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_b2a9e_row2_col5, #T_b2a9e_row5_col6 {
#   background-color: #e38a9c;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_b2a9e_row2_col7, #T_b2a9e_row6_col1 {
#   background-color: #e8aab6;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_b2a9e_row2_col8 {
#   background-color: #e59aa9;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_b2a9e_row2_col9 {
#   background-color: #e7eaef;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_b2a9e_row2_col10 {
#   background-color: #f2eeef;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_b2a9e_row3_col0 {
#   background-color: #a6bdda;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_b2a9e_row3_col1 {
#   background-color: #eab7c1;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_b2a9e_row3_col4 {
#   background-color: #9bb6d7;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_b2a9e_row3_col5 {
#   background-color: #96b2d5;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_b2a9e_row3_col7 {
#   background-color: #b0c4dd;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_b2a9e_row3_col8 {
#   background-color: #9fb8d8;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_b2a9e_row3_col10 {
#   background-color: #db526e;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_b2a9e_row4_col0 {
#   background-color: #eed2d7;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_b2a9e_row4_col1, #T_b2a9e_row7_col1 {
#   background-color: #dfe5ed;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_b2a9e_row4_col3 {
#   background-color: #8dacd2;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_b2a9e_row4_col5 {
#   background-color: #5887c1;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_b2a9e_row4_col7, #T_b2a9e_row7_col4 {
#   background-color: #477bbb;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_b2a9e_row4_col9 {
#   background-color: #db5570;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_b2a9e_row4_col10 {
#   background-color: #eed4d9;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_b2a9e_row5_col0 {
#   background-color: #eeeff2;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_b2a9e_row5_col1 {
#   background-color: #e4e9ee;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_b2a9e_row5_col2 {
#   background-color: #e8abb7;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_b2a9e_row5_col3 {
#   background-color: #88a8d0;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_b2a9e_row5_col4 {
#   background-color: #5786c1;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_b2a9e_row5_col7 {
#   background-color: #5383bf;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_b2a9e_row5_col8, #T_b2a9e_row7_col5, #T_b2a9e_row8_col5 {
#   background-color: #5484c0;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_b2a9e_row6_col0 {
#   background-color: #c7d4e5;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_b2a9e_row6_col2 {
#   background-color: #efdcdf;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_b2a9e_row6_col3 {
#   background-color: #e597a7;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_b2a9e_row6_col5 {
#   background-color: #e28497;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_b2a9e_row6_col7 {
#   background-color: #d84462;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_b2a9e_row6_col8 {
#   background-color: #d8405e;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_b2a9e_row6_col9 {
#   background-color: #eaecf0;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_b2a9e_row6_col10 {
#   background-color: #e9b5bf;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_b2a9e_row7_col2, #T_b2a9e_row10_col4 {
#   background-color: #eabcc5;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_b2a9e_row7_col3 {
#   background-color: #a1b9d9;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_b2a9e_row7_col8, #T_b2a9e_row8_col7 {
#   background-color: #457abb;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_b2a9e_row7_col9 {
#   background-color: #d94663;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_b2a9e_row8_col0 {
#   background-color: #ecc9d0;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_b2a9e_row8_col1 {
#   background-color: #dce3ec;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_b2a9e_row8_col3 {
#   background-color: #90aed3;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_b2a9e_row8_col9 {
#   background-color: #da4e6a;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_b2a9e_row8_col10 {
#   background-color: #eed6db;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_b2a9e_

# %% [markdown]
# ## Models

# %%
# prepare the data for the model
# select the only NOX as target variabel
nox_df = df.copy()
nox_df = nox_df.drop("CO", axis = 1) # drop the target variable CO

# %%
# split the data for training and test using sklearn train_test_split function 
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import Normalizer

# split the data 
X = nox_df.iloc[:, 0:-1]
y = nox_df["NOX"]

# normalize the X and y.
X = nox_df = Normalizer().fit_transform(X)
# normalize the data 

X_train, X_test, y_train, y_test = train_test_split(X, y,  test_size = 0.2,random_state= 0, shuffle = True)

# %%
#Model 1:linear Regression

# %%
# import the packges for linear regression
from sklearn.linear_model import LinearRegression
linear_model = LinearRegression ()
linear_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# import the packges for linear regression
from sklearn.linear_model import LinearRegression
linear_model = LinearRegression ()
linear_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# evalute the model with MAE
from sklearn.metrics import mean_absolute_error
y_pred = linear_model.predict(X_test)
mae_linear = mean_absolute_error(y_test, y_pred)
print("MAE on testset is:", round(mae_linear, 3))
# Out:
# MAE on testset is: 6.844
